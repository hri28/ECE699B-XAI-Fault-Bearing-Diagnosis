# %%
# -*- coding: utf-8 -*-
"""
# -----------------------------------------------------------------------------
Created on Tue Aug 13 23:41:44 2024

@author: YLiu
# -----------------------------------------------------------------------------
"""

"""
# -----------------------------------------------------------------------------
# Setup Initial Python Code for Reproducibility
# -----------------------------------------------------------------------------
"""

import tensorflow as tf
import numpy as np
import random
import os

# Set a fixed seed value for reproducibility
SEED = 1
random.seed(SEED)            # Python random module
np.random.seed(SEED)         # NumPy
tf.random.set_seed(SEED)     # TensorFlow

# Enforce deterministic behavior for GPU operations
os.environ['TF_DETERMINISTIC_OPS'] = '1'  # Ensure deterministic execution
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'  # Deterministic cuDNN algorithms

# Control GPU memory allocation (prevents TensorFlow from using all GPU memory)
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)  # Enable memory growth

# Restrict parallelism (ensures consistent execution order)
tf.config.threading.set_inter_op_parallelism_threads(1)
tf.config.threading.set_intra_op_parallelism_threads(1)


# import os
import scipy.io
# import numpy as np
from sklearn.model_selection import train_test_split #, KFold
from sklearn.metrics import confusion_matrix
# import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt
import seaborn as sns
# import pandas as pd

from scipy import signal
from skimage.transform import resize
from sklearn.model_selection import StratifiedKFold

"""
# -----------------------------------------------------------------------------
# Read CWRU Bearing Data (Load - 2HP)
# -----------------------------------------------------------------------------
"""
def ImportData():
  folder_path = '/content/BearingData_CaseWestern_48K1750'
  # X99_normal = scipy.io.loadmat('content/drive/MyDrive/BearingData_CaseWestern/99.mat')['X099_DE_time']
  file_path1 = os.path.join(folder_path, '99.mat')
  X99_normal = scipy.io.loadmat(file_path1)['X099_DE_time']

  # X111_InnerRace_007 = scipy.io.loadmat('/content/drive/MyDrive/BearingData_CaseWestern/111.mat')['X111_DE_time']
  file_path2 = os.path.join(folder_path, '111.mat')
  X111_InnerRace_007  = scipy.io.loadmat(file_path2)['X111_DE_time']

  # X124_Ball_007 = scipy.io.loadmat('/content/drive/MyDrive/BearingData_CaseWestern/124.mat')['X124_DE_time']
  file_path3 = os.path.join(folder_path, '124.mat')
  X124_Ball_007 = scipy.io.loadmat(file_path3)['X124_DE_time']

  # X137_Outer_007 = scipy.io.loadmat('/content/drive/MyDrive/BearingData_CaseWestern/137.mat')['X137_DE_time']
  file_path4 = os.path.join(folder_path, '137.mat')
  X137_Outer_007 = scipy.io.loadmat(file_path4)['X137_DE_time']

  # X176_InnerRace_014 = scipy.io.loadmat('/content/drive/MyDrive/BearingData_CaseWestern/176.mat')['X176_DE_time']
  file_path5 = os.path.join(folder_path, '176.mat')
  X176_InnerRace_014 = scipy.io.loadmat(file_path5)['X176_DE_time']

  # X191_Ball_014 = scipy.io.loadmat('/content/drive/MyDrive/BearingData_CaseWestern/191.mat')['X191_DE_time']
  file_path6 = os.path.join(folder_path, '191.mat')
  X191_Ball_014 = scipy.io.loadmat(file_path6)['X191_DE_time']

  # X203_Outer_014 = scipy.io.loadmat('/content/drive/MyDrive/BearingData_CaseWestern/203.mat')['X203_DE_time']
  file_path7 = os.path.join(folder_path, '203.mat')
  X203_Outer_014  = scipy.io.loadmat(file_path7)['X203_DE_time']

  #  X215_InnerRace_021 = scipy.io.loadmat('/content/drive/MyDrive/BearingData_CaseWestern/215.mat')['X215_DE_time']
  file_path8 = os.path.join(folder_path, '215.mat')
  X215_InnerRace_021  = scipy.io.loadmat(file_path8)['X215_DE_time']

  # X228_Ball_021 = scipy.io.loadmat('/content/drive/MyDrive/BearingData_CaseWestern/228.mat')['X228_DE_time']
  file_path9 = os.path.join(folder_path, '228.mat')
  X228_Ball_021  = scipy.io.loadmat(file_path9)['X228_DE_time']

  # X240_Outer_021 = scipy.io.loadmat('/content/drive/MyDrive/BearingData_CaseWestern/240.mat')['X240_DE_time']
  file_path10 = os.path.join(folder_path, '240.mat')
  X240_Outer_021  = scipy.io.loadmat(file_path10)['X240_DE_time']

  return [X99_normal,X111_InnerRace_007,X124_Ball_007,X137_Outer_007,X176_InnerRace_014,X191_Ball_014,X203_Outer_014,X215_InnerRace_021,X228_Ball_021,X240_Outer_021]

"""
# -----------------------------------------------------------------------------
# Data Processing and Feature Extraction
# -----------------------------------------------------------------------------
"""
# def Sampling(Data, interval_length, samples_per_block):
#     No_of_blocks = (round(len(Data)/interval_length) - round(samples_per_block/interval_length) - 1)
#     SplitData = np.zeros([No_of_blocks, samples_per_block])
#     for i in range(No_of_blocks):
#         SplitData[i,:] = Data[i*interval_length:(i*interval_length)+samples_per_block].T
#     return SplitData

def Sampling(Data, interval_length, samples_per_block, ignore_points=0):
    # Adjust data length to ignore the first and last 'ignore_points'
    adjusted_length = len(Data) - 2 * ignore_points
    # Adjust the number of blocks
    No_of_blocks = (round(adjusted_length / interval_length) - round(samples_per_block / interval_length) - 1)
    SplitData = np.zeros([No_of_blocks, samples_per_block])

    for i in range(No_of_blocks):
        # Skip the first 'ignore_points' and start sampling from that position
        start_idx = ignore_points + i * interval_length
        SplitData[i, :] = Data[start_idx:(start_idx + samples_per_block)].T

    return SplitData


def DataPreparation(Data, interval_length, samples_per_block):
  for count,i in enumerate(Data):
    SplitData = Sampling(i, interval_length, samples_per_block)
    y = np.zeros([len(SplitData),10])
    y[:,count] = 1
    y1 = np.zeros([len(SplitData),1])
    y1[:,0] = count
    # Stack up and label the data
    if count==0:
      X = SplitData
      LabelPositional = y
      Label = y1
    else:
      X = np.append(X, SplitData, axis=0)
      LabelPositional = np.append(LabelPositional,y,axis=0)
      Label = np.append(Label,y1,axis=0)
  return X, LabelPositional, Label


def min_max_norm(ary):
    ary = (ary - ary.min()) / np.abs(ary.max() - ary.min())
    return ary


def generate_spectrogram_image(data_y_vector, image_shape):
    """
    Calculate the spectrogram of an array data_y_vector and resize it in
    the image_shape resolution
    """
    fs = 48000
    # data_y_vector_len = np.shape(data_y_vector)[0]

    f, t, sxx = signal.spectrogram(
        data_y_vector,
        fs)

    sxx = min_max_norm(sxx)
    sxx = resize(sxx, image_shape, mode='constant', anti_aliasing=True)

    return sxx


Data = ImportData()
interval_length = 1600 #320 #290 #200
samples_per_block = 1600 #1650-25*2


# Y_CNN is of shape (n, 10) representing 10 classes as 10 columns. In each sample, for the class to which it belongs,
# the corresponding column value is marked 1 and the rest as 0, facilitating Softmax implementation in CNN
# Y is of shape (m, 1) where column values are between 0 and 9 representing the classes directly. - 1-hot encoding
X, Y_CNN, Y = DataPreparation(Data, interval_length, samples_per_block)


print('Shape of Input Data =', X.shape)
print('Shape of Label Y_CNN =', Y_CNN.shape)
print('Shape of Label Y =', Y.shape)

# XX = {'X':X}
# scipy.io.savemat('Data.mat', XX)

"""
# -----------------------------------------------------------------------------
# Multiclass Classification CNN Model Training
# -----------------------------------------------------------------------------
"""

# k-fold cross validation
kSplits = 5
# kfold = KFold(n_splits=kSplits, random_state=42, shuffle=True)
kfold = StratifiedKFold(n_splits=kSplits, random_state=42, shuffle=True)

## 2-Dimensional Convolutional Neural Network Classification

# Reshape the data - 2 dimensional feed
Input_2D = X.reshape([-1,40,40,1])

# Input_2D = X_image.reshape([-1,96,96,1])
print(Input_2D.shape)

# Test-Train Split
X_2D_train, X_2D_test, y_2D_train, y_2D_test, y_label_train, y_label_test = train_test_split(Input_2D, Y_CNN, Y, train_size=0.8, test_size=0.2, random_state=42, stratify=Y)
# X_2D_train, X_2D_test, y_2D_train, y_2D_test = train_test_split(Input_2D, Y_CNN, train_size=0.8, test_size=0.2, random_state=42, shuffle=True)

# Define the CNN Classification model
class CNN_2D():
  def __init__(self):
    self.model = self.CreateModel()

  def CreateModel(self):
    model = models.Sequential([
        # layers.Conv2D(filters=16, kernel_size=(3,3), strides=(2,2), padding ='same',activation='relu'),
        layers.Conv2D(filters=16, kernel_size=(3,3), padding='same',activation='relu', input_shape=(40,40,1)),
        layers.MaxPool2D(pool_size=(2,2), padding='same'),
        layers.Conv2D(filters=32, kernel_size=(3,3), padding ='same',activation='relu'),
        layers.MaxPool2D(pool_size=(2,2), padding='same'),
        layers.Conv2D(filters=64, kernel_size=(3,3),padding ='same', activation='relu'),
        layers.MaxPool2D(pool_size=(2,2), padding='same'),
        layers.Conv2D(filters=128, kernel_size=(3,3),padding ='same', activation='relu'),
        layers.MaxPool2D(pool_size=(2,2), padding='same'),
        layers.Flatten(),
        #layers.InputLayer(),
        layers.Dense(100,activation='relu'),
        layers.Dense(50,activation='relu'),
        layers.Dense(10),
        layers.Softmax()
        ])
    model.compile(optimizer='adam',
              loss=tf.keras.losses.CategoricalCrossentropy(),
              metrics=['accuracy'])
    return model

# File path name to save best models
foldername = "CNN2D_results/V4_2_NOL_exp1/"

from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import load_model

accuracy_train = []
accuracy_val = []
accuracy_test = []
pred_all_val = np.zeros([len(X_2D_train),10])
y_2D_val = np.zeros([len(X_2D_train),10])
kfold_test_len = []

fl1 = 0
k = 1

early_stop = EarlyStopping(monitor='val_accuracy', patience=50, restore_best_weights=True)

# Train the model
# for train, test in kfold.split(X_2D_train,y_2D_train):
for fold, (train, test) in enumerate(kfold.split(X_2D_train, y_label_train)):

  # Define where to save the best model
  checkpoint_filepath = foldername + "best_model_" + str(k) + ".h5"

  # Create a ModelCheckpoint callback
  checkpoint = ModelCheckpoint(
      filepath=checkpoint_filepath,
      monitor='val_accuracy',  # Monitor validation accuracy
      save_best_only=True,  # Save only the best model
      mode='max',  # Maximize accuracy
      verbose=1
  )

  Classification_2D = CNN_2D()
  # history = Classification_2D.model.fit(X_2D_train[train], y_2D_train[train], verbose=1, epochs=50) #epochs=12
  history = Classification_2D.model.fit(
        X_2D_train[train], y_2D_train[train],
        validation_data=(X_2D_train[test], y_2D_train[test]),  # Validation set for monitoring
        epochs=200,
        verbose=1,
        callbacks=[checkpoint, early_stop]  # Save the best model
  )

  print("Best model saved at:", checkpoint_filepath)
  CNN_2D_best_model = load_model(checkpoint_filepath)
  print("Best model loaded successfully!")

  fl2 = fl1 + len(test)
  pred_all_val[fl1:fl2,:] = CNN_2D_best_model.predict(X_2D_train[test])
  y_2D_val[fl1:fl2,:] = y_2D_train[test]
  kfold_test_len.append(fl2-fl1)
  fl1 = fl2

  # Evaluate the accuracy of the model on the training set
  train_loss, train_accuracy = CNN_2D_best_model.evaluate(X_2D_train[train], y_2D_train[train])
  accuracy_train.append(train_accuracy)

  # Evaluate the accuracy of the model on the validation set
  val_loss, val_accuracy = CNN_2D_best_model.evaluate(X_2D_train[test], y_2D_train[test])
  accuracy_val.append(val_accuracy)

  # Evaluate the accuracy of the model on the validation set
  test_loss, test_accuracy = CNN_2D_best_model.evaluate(X_2D_test, y_2D_test)
  accuracy_test.append(test_accuracy)

  # Evaluate the accuracy of the model on the training set
  # kf_loss, kf_accuracy = Classification_2D.model.evaluate(X_2D_train[test], y_2D_train[test])
  # accuracy_2D.append(kf_accuracy)

  k = k + 1

"""
# -----------------------------------------------------------------------------
# Multiclass Classification CNN Model Evaluation
# -----------------------------------------------------------------------------
"""

# Classification_2D.model.summary()

CNN_2D_train_accuracy = np.average(accuracy_train)*100
print('CNN 2D train accuracy =', CNN_2D_train_accuracy)
# print(accuracy_train)

CNN_2D_val_accuracy = np.average(accuracy_val)*100
print('CNN 2D validation accuracy =', CNN_2D_val_accuracy)
# print(accuracy_val)

CNN_2D_test_accuracy = np.average(accuracy_test)*100
print('CNN 2D test accuracy =', CNN_2D_test_accuracy)
# print(accuracy_test)

# Evaluate the accuracy of the model on the test set
# CNN_2D_test_loss, CNN_2D_test_accuracy = Classification_2D.model.evaluate(X_2D_test, y_2D_test)
# CNN_2D_test_accuracy*=100
# print('CNN 2D test accuracy =', CNN_2D_test_accuracy)


def ConfusionMatrix(Model, X, y):
  y_pred = np.argmax(Model.predict(X), axis=1)
  ConfusionMat = confusion_matrix(np.argmax(y, axis=1), y_pred)
  return ConfusionMat

# Plot results - CNN 2D
plt.figure(5)
plt.title('Confusion Matrix - CNN 2D Train')
sns.heatmap(ConfusionMatrix(CNN_2D_best_model, X_2D_train, y_2D_train) , annot=True, fmt='d',annot_kws={"fontsize":8},cmap="YlGnBu")
plt.show()

plt.figure(6)
plt.title('Confusion Matrix - CNN 2D Test')
sns.heatmap(ConfusionMatrix(CNN_2D_best_model, X_2D_test, y_2D_test) , annot=True, fmt='d',annot_kws={"fontsize":8},cmap="YlGnBu")
plt.show()

plt.figure(7)
plt.title('Train - Accuracy - CNN 2D')
plt.bar(np.arange(1,kSplits+1),[i*100 for i in accuracy_val])
plt.ylabel('accuracy')
plt.xlabel('folds')
plt.ylim([70,100])
plt.show()

plt.figure(8)
plt.title('Train vs Test Accuracy - CNN 2D')
plt.bar([1,2],[CNN_2D_train_accuracy,CNN_2D_test_accuracy])
plt.ylabel('accuracy')
plt.xlabel('folds')
plt.xticks([1,2],['Train', 'Test'])
plt.ylim([70,100])
plt.show()
# Out:
# Shape of Input Data = (3026, 1600)
# Shape of Label Y_CNN = (3026, 10)
# Shape of Label Y = (3026, 1)
# (3026, 40, 40, 1)
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/200
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.2435 - loss: 2.0297
# Epoch 1: val_accuracy improved from -inf to 0.65909, saving model to CNN2D_results/V4_2_NOL_exp1/best_model_1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 75ms/step - accuracy: 0.2478 - loss: 2.0191 - val_accuracy: 0.6591 - val_loss: 0.9968
# Epoch 2/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.7124 - loss: 0.7726
# Epoch 2: val_accuracy improved from 0.65909 to 0.73554, saving model to CNN2D_results/V4_2_NOL_exp1/best_model_1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 5s 81ms/step - accuracy: 0.7130 - loss: 0.7706 - val_accuracy: 0.7355 - val_loss: 0.6189
# Epoch 3/200
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.
val_accuracy did not improve from 0.98554
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - accuracy: 1.0000 - loss: 2.1789e-05 - val_accuracy: 0.9814 - val_loss: 0.0686
# Epoch 95/200
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 1.0000 - loss: 2.0830e-05
# Epoch 95: val_accuracy did not improve from 0.98554
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 5s 74ms/step - accuracy: 1.0000 - loss: 2.0821e-05 - val_accuracy: 0.9814 - val_loss: 0.0688
# Epoch 96/200
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 1.0000 - loss: 1.9954e-05
# Epoch 96: val_accuracy did not improve from 0.98554
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - accuracy: 1.0000 - loss: 1.9946e-05 - val_accuracy: 0.9814 - val_loss: 0.0688
# Epoch 97/200
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 1.0000 - loss: 1.9036e-05
# Epoch 97: val_accuracy did not improve from 0.98554
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - accuracy: 1.0000 - loss: 1.9031e-05 - val_accuracy: 0.9814 - val_loss: 0.0689
# Epoch 98/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 1.0000 - loss: 1.8220e-05
# Epoch 98: val_accuracy did not improve from 0.98554
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 5s 81ms/step - accuracy: 1.0000 - loss: 1.8218e-05 - val_accuracy: 0.9814 - val_loss: 0.0691
# Epoch 99/200
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 1.0000 - loss: 1.7485e-05
# Epoch 99: val_accuracy did not improve from 0.98554
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 5s 75ms/step - accuracy: 1.0000 - loss: 1.7481e-05 - val_accuracy: 0.9814 - val_loss: 0.0692
# Epoch 100/200
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 1.0000 - loss: 1.6711e-05
# Epoch 100: val_accuracy did not improve from 0.98554
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - accuracy: 1.0000 - loss: 1.6708e-05 - val_accuracy: 0.9814 - val_loss: 0.0692
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Best model saved at: CNN2D_results/V4_2_NOL_exp1/best_model_1.h5
# Best model loaded successfully!
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 1.0000 - loss: 5.9166e-04
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9836 - loss: 0.0486
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.9859 - loss: 0.0444
# Epoch 1/200
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.2011 - loss: 2.0290
# Epoch 1: val_accuracy improved from -inf to 0.58678, saving model to CNN2D_results/V4_2_NOL_exp1/best_model_2.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 75ms/step - accuracy: 0.2058 - loss: 2.0197 - val_accuracy: 0.5868 - val_loss: 1.0321
# Epoch 2/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6724 - loss: 0.8824
# Epoch 2: val_accuracy improved from 0.58678 to 0.74174, saving model to CNN2D_results/V4_2_NOL_exp1/best_model_2.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - accuracy: 0.6730 - loss: 0.8803 - val_accuracy: 0.7417 - val_loss: 0.6014
# Epoch 3/200
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.7983 - loss: 0.4864
# Epoch 3: val_accuracy did not improve from 0.74174
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 5s 80ms/step - accuracy: 0.7986 - loss: 0.4851 - val_accuracy: 0.7397 - val_loss: 0.6269
# Epoch 4/200
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.7880 - loss: 0.4841
# Epoch 4: val_accuracy improved from 0.74174 to 0.80372, saving model to CNN2D_results/V4_2_NOL_exp1/best_model_2.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - accuracy: 0.7884 - loss: 0.4828 - val_accuracy: 0.8037 - val_loss: 0.4199
# Epoch 5/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.7989 - loss: 0.4686
# Epoch 5: val_accuracy improved from 0.80372 to 0.81818, saving model to CNN2D_results/V4_2_NOL_exp1/best_model_2.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 5s 85ms/step - accuracy: 0.7991 - loss: 0.4682 - val_accuracy: 0.8182 - val_loss: 0.3997
# Epoch 6/200
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.8487 - loss: 0.3438
# Epoch 6: val_accuracy improved from 0.81818 to 0.82645, saving model to CNN2D_results/V4_2_NOL_exp1/best_model_2.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - accuracy: 0.8485 - loss: 0.3438 - val_accuracy: 0.8264 - val_loss: 0.3611
# Epoch 7/200
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.8596 - loss: 0.2828
# Epoch 7: val_accuracy improved from 0.82645 to 0.87810, saving model to CNN2D_results/V4_2_NOL_exp1/best_model_2.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - accuracy: 0.8592 - loss: 0.2837 - val_accuracy: 0.8781 - val_loss: 0.3281
# Epoch 8/200
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.8874 - loss: 0.2548
# Epoch 8: val_accuracy did not improve from 0.87810
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 5s 86ms/step - accuracy: 0.8869 - loss: 0.2551 - val_accuracy: 0.8471 - val_loss: 0.3243
# Epoch 9/200
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.8779 - loss: 0.2462
# Epoch 9: val_accuracy did not improve from 0.87810
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - accuracy: 0.8779 - loss: 0.2461 - val_accuracy: 0.8285 - val_loss: 0.3716
# Epoch 10/200
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.8725 - loss: 0.2617
# Epoch 10: val_accuracy did not improve from 0.87810
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.8723 - loss: 0.2619 - val_accuracy: 0.8368 - val_loss: 0.3555
# Epoch 11/200
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.8569 - loss: 0.2906
# Epoch 11: val_accuracy did not improve from 0.87810
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 5s 87ms/step - accuracy: 0.8570 - loss: 0.2904 - val_accuracy: 0.8430 - val_loss: 0.3408
# Epoch 12/200
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.8724 - loss: 0.2237
# Epoch 12: val_accuracy did not improve from 0.87810
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - accuracy: 0.8728 - loss: 0.2232 - val_accuracy: 0.8760 - val_loss: 0.2736
# Epoch 13/200
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.
200
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.9888 - loss: 0.0310
# Epoch 30: val_accuracy did not improve from 0.96694
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 5s 87ms/step - accuracy: 0.9889 - loss: 0.0307 - val_accuracy: 0.9483 - val_loss: 0.1786
# Epoch 31/200
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9913 - loss: 0.0238
# Epoch 31: val_accuracy did not improve from 0.96694
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.9913 - loss: 0.0236 - val_accuracy: 0.9566 - val_loss: 0.1358
# Epoch 32/200
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9923 - loss: 0.0194
# Epoch 32: val_accuracy did not improve from 0.96694
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.9924 - loss: 0.0194 - val_accuracy: 0.9442 - val_loss: 0.2238
# Epoch 33/200
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9929 - loss: 0.0169
# Epoch 33: val_accuracy did not improve from 0.96694
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 5s 86ms/step - accuracy: 0.9929 - loss: 0.0169 - val_accuracy: 0.9607 - val_loss: 0.1436
# Epoch 34/200
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9937 - loss: 0.0177
# Epoch 34: val_accuracy did not improve from 0.96694
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - accuracy: 0.9937 - loss: 0.0178 - val_accuracy: 0.9525 - val_loss: 0.1575
# Epoch 35/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.9695 - loss: 0.0889
# Epoch 35: val_accuracy did not improve from 0.96694
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - accuracy: 0.9694 - loss: 0.0895 - val_accuracy: 0.8905 - val_loss: 0.3486
# Epoch 36/200
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9235 - loss: 0.2490
# Epoch 36: val_accuracy did not improve from 0.96694
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 5s 79ms/step - accuracy: 0.9235 - loss: 0.2488 - val_accuracy: 0.9483 - val_loss: 0.1412
# Epoch 37/200
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9776 - loss: 0.0529
# Epoch 37: val_accuracy improved from 0.96694 to 0.96901, saving model to CNN2D_results/V4_2_NOL_exp1/best_model_2.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - accuracy: 0.9777 - loss: 0.0526 - val_accuracy: 0.9690 - val_loss: 0.1075
# Epoch 38/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.9866 - loss: 0.0295
# Epoch 38: val_accuracy did not improve from 0.96901
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 5s 88ms/step - accuracy: 0.9866 - loss: 0.0295 - val_accuracy: 0.9649 - val_loss: 0.1203
# Epoch 39/200
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9863 - loss: 0.0296
# Epoch 39: val_accuracy did not improve from 0.96901
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.9863 - loss: 0.0296 - val_accuracy: 0.9545 - val_loss: 0.1456
# Epoch 40/200
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9891 - loss: 0.0255
# Epoch 40: val_accuracy did not improve from 0.96901
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.9890 - loss: 0.0257 - val_accuracy: 0.9298 - val_loss: 0.2187
# Epoch 41/200
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9952 - loss: 0.0233
# Epoch 41: val_accuracy did not improve from 0.96901
# ...
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 5s 88ms/step - accuracy: 1.0000 - loss: 1.5089e-04 - val_accuracy: 0.9959 - val_loss: 0.0408
# Epoch 65/200
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 1.0000 - loss: 1.4005e-04
# Epoch 65: val_accuracy did not improve from 0.99587
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - accuracy: 1.0000 - loss: 1.3987e-04 - val_accuracy: 0.9959 - val_loss: 0.0404
# Epoch 66/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 1.0000 - loss: 1.3017e-04
# Epoch 66: val_accuracy did not improve from 0.99587
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 5s 80ms/step - accuracy: 1.0000 - loss: 1.3009e-04 - val_accuracy: 0.9959 - val_loss: 0.0401
# Epoch 67/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 1.0000 - loss: 1.2142e-04
# Epoch 67: val_accuracy did not improve from 0.99587
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 6s 97ms/step - accuracy: 1.0000 - loss: 1.2135e-04 - val_accuracy: 0.9959 - val_loss: 0.0398
# Epoch 68/200
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 1.0000 - loss: 1.1362e-04
# Epoch 68: val_accuracy did not improve from 0.99587
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - accuracy: 1.0000 - loss: 1.1348e-04 - val_accuracy: 0.9959 - val_loss: 0.0396
# Epoch 69/200
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 1.0000 - loss: 1.0649e-04
# Epoch 69: val_accuracy did not improve from 0.99587
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 5s 88ms/step - accuracy: 1.0000 - loss: 1.0636e-04 - val_accuracy: 0.9959 - val_loss: 0.0393
# Epoch 70/200
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 1.0000 - loss: 9.9976e-05
# Epoch 70: val_accuracy improved from 0.99587 to 0.99793, saving model to CNN2D_results/V4_2_NOL_exp1/best_model_5.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - accuracy: 1.0000 - loss: 9.9853e-05 - val_accuracy: 0.9979 - val_loss: 0.0391
# Epoch 71/200
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 1.0000 - loss: 9.4006e-05
# Epoch 71: val_accuracy did not improve from 0.99793
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - accuracy: 1.0000 - loss: 9.3890e-05 - val_accuracy: 0.9979 - val_loss: 0.0389
# Epoch 72/200
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 1.0000 - loss:
200
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 1.0000 - loss: 2.7957e-05
# Epoch 95: val_accuracy did not improve from 0.99793
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - accuracy: 1.0000 - loss: 2.7922e-05 - val_accuracy: 0.9979 - val_loss: 0.0350
# Epoch 96/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 1.0000 - loss: 2.6741e-05
# Epoch 96: val_accuracy did not improve from 0.99793
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 5s 87ms/step - accuracy: 1.0000 - loss: 2.6724e-05 - val_accuracy: 0.9979 - val_loss: 0.0349
# Epoch 97/200
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 2.5621e-05
# Epoch 97: val_accuracy did not improve from 0.99793
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - accuracy: 1.0000 - loss: 2.5588e-05 - val_accuracy: 0.9979 - val_loss: 0.0348
# Epoch 98/200
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 1.0000 - loss: 2.4508e-05
# Epoch 98: val_accuracy did not improve from 0.99793
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - accuracy: 1.0000 - loss: 2.4477e-05 - val_accuracy: 0.9979 - val_loss: 0.0347
# Epoch 99/200
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 1.0000 - loss: 2.3505e-05
# Epoch 99: val_accuracy did not improve from 0.99793
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 5s 88ms/step - accuracy: 1.0000 - loss: 2.3475e-05 - val_accuracy: 0.9979 - val_loss: 0.0346
# Epoch 100/200
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 1.0000 - loss: 2.2523e-05
# Epoch 100: val_accuracy did not improve from 0.99793
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - accuracy: 1.0000 - loss: 2.2494e-05 - val_accuracy: 0.9959 - val_loss: 0.0346
# Epoch 101/200
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 1.0000 - loss: 2.1566e-05
# Epoch 101: val_accuracy did not improve from 0.99793
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - accuracy: 1.0000 - loss: 2.1538e-05 - val_accuracy: 0.9959 - val_loss: 0.0345
# Epoch 102/200
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 1.0000 - loss: 2.0695e-05
# Epoch 102: val_accuracy did not improve from 0.99793
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 5s 89ms/step - accuracy: 1.0000 - loss: 2.0668e-05 - val_accuracy: 0.9959 - val_loss: 0.0344
# Epoch 103/200
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 1.0000 - loss: 1.9841e-05
# Epoch 103: val_accuracy did not improve from 0.99793
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - accuracy: 1.0000 - loss: 1.9815e-05 - val_accuracy: 0.9959 - val_loss: 0.0344
# Epoch 104/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 1.0000 - loss: 1.9003e-05
# Epoch 104: val_accuracy did not improve from 0.99793
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 5s 79ms/step - accuracy: 1.0000 - loss: 1.8991e-05 - val_accuracy: 0.9959 - val_loss: 0.0344
# Epoch 105/200
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 1.0000 - loss: 1.8258e-05
# Epoch 105: val_accuracy did not improve from 0.99793
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 5s 80ms/step - accuracy: 1.0000 - loss: 1.8234e-05 - val_accuracy: 0.9959 - val_loss: 0.0345
# Epoch 106/200
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 1.7508e-05
# Epoch 106: val_accuracy did not improve from 0.99793
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - accuracy: 1.0000 - loss: 1.7486e-05 - val_accuracy: 0.9959 - val_loss: 0.0345
# Epoch 107/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 1.0000 - loss: 1.6801e-05
# Epoch 107: val_accuracy did not improve from 0.99793
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 5s 88ms/step - accuracy: 1.0000 - loss: 1.6790e-05 - val_accuracy: 0.9959 - val_loss: 0.0345
# Epoch 108/200
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 1.0000 - loss: 1.6127e-05
# Epoch 108: val_accuracy did not improve from 0.99793
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - accuracy: 1.0000 - loss: 1.6107e-05 - val_accuracy: 0.9959 - val_loss: 0.0345
# Epoch 109/200
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 1.5497e-05
# Epoch 109: val_accuracy did not improve from 0.99793
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - accuracy: 1.0000 - loss: 1.5477e-05 - val_accuracy: 0.9959 - val_loss: 0.0345
# Epoch 110/200
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 1.0000 - loss: 1.4866e-05
# Epoch 110: val_accuracy did not improve from 0.99793
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 5s 88ms/step - accuracy: 1.0000 - loss: 1.4847e-05 - val_accuracy: 0.9959 - val_loss: 0.0345
# Epoch 111/200
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 1.4290e-05
# Epoch 111: val_accuracy did not improve from 0.99793
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - accuracy: 1.0000 - loss: 1.4271e-05 - val_accuracy: 0.9959 - val_loss: 0.0345
# Epoch 112/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 1.0000 - loss: 1.3700e-05
# Epoch 112: val_accuracy did not improve from 0.99793
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 6s 96ms/step - accuracy: 1.0000 - loss: 1.3691e-05 - val_accuracy: 0.9959 - val_loss: 0.0346
# Epoch 113/200
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 1.0000 - loss: 1.3183e-05
# Epoch 113: val_accuracy did not improve from 0.99793
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 5s 81ms/step - accuracy: 1.0000 - loss: 1.3165e-05 - val_accuracy: 0.9959 - val_loss: 0.0346
# Epoch 114/200
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 1.0000 - loss: 1.2655e-05
# Epoch 114: val_accuracy did not improve from 0.99793
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - accuracy: 1.0000 - loss: 1.2639e-05 - val_accuracy: 0.9959 - val_loss: 0.0346
# Epoch 115/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 1.0000 - loss: 1.2152e-05
# Epoch 115: val_accuracy did not improve from 0.99793
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 5s 90ms/step - accuracy: 1.0000 - loss: 1.2144e-05 - val_accuracy: 0.9959 - val_loss: 0.0346
# Epoch 116/200
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 1.1699e-05
# Epoch 116: val_accuracy did not improve from 0.99793
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - accuracy: 1.0000 - loss: 1.1683e-05 - val_accuracy: 0.9959 - val_loss: 0.0346
# Epoch 117/200
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 1.1228e-05
# Epoch 117: val_accuracy did not improve from 0.99793
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - accuracy: 1.0000 - loss: 1.1213e-05 - val_accuracy: 0.9959 - val_loss: 0.0347
# Epoch 118/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 1.0000 - loss: 1.0801e-05
# Epoch 118: val_accuracy did not improve from 0.99793
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 6s 86ms/step - accuracy: 1.0000 - loss: 1.0794e-05 - val_accuracy: 0.9959 - val_loss: 0.0347
# Epoch 119/200
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 1.0378e-05
# Epoch 119: val_accuracy did not improve from 0.99793
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - accuracy: 1.0000 - loss: 1.0364e-05 - val_accuracy: 0.9959 - val_loss: 0.0347
# Epoch 120/200
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 1.0000 - loss: 9.9842e-06
# Epoch 120: val_accuracy did not improve from 0.99793
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 5s 85ms/step - accuracy: 1.0000 - loss: 9.9777e-06 - val_accuracy: 0.9959 - val_loss: 0.0348
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Best model saved at: CNN2D_results/V4_2_NOL_exp1/best_model_5.h5
# Best model loaded successfully!
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 1.0000 - loss: 7.0648e-05
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9987 - loss: 0.0282
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9951 - loss: 0.0228
# CNN 2D train accuracy = 100.0
# CNN 2D validation accuracy = 98.30578446388245
# CNN 2D test accuracy = 97.65676617622375
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
